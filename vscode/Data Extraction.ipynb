# %%
import os
from google.cloud import bigquery

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r"C:\path\your-google-analytics-key.json"

client = bigquery.Client()

# %% [markdown]
# The dataset 'bigquery-public-data.google_analytics_sample.ga_sessions_*' from **Google Analytics Sample** as a google cloud public data has the following columns:
#
# - visitorId
# - visitNumber
# - visitId
# - visitStartTime
# - date
# - totals
# - trafficSource
# - device
# - geoNetwork
# - customDimensions
# - hits
# - fullVisitorId
# - userId
# - channelGrouping
# - socialEngagement

# %%
# Extract count of visits in each channel grouping in 2017 July
query = """
SELECT
  channelGrouping,
  COUNT(visitId) AS number_of_visits
FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
WHERE _TABLE_SUFFIX BETWEEN '20170701' AND '20170731'
GROUP BY channelGrouping
HAVING number_of_visits > 0
ORDER BY number_of_visits DESC;
"""

# Execute the query and store the results in a Pandas DataFrame
df = client.query(query).to_dataframe()

# Display the first few rows
df.head()
# Out:
#   channelGrouping  number_of_visits
# 0  Organic Search             37655
# 1          Direct             12306
# 2        Referral              9518
# 3          Social              7749
# 4     Paid Search              2105

# %% [markdown]
# # Data Structure

# %%
import pandas as pd
import numpy as np

# %%
# Extract count of visits in each channel grouping from a sample date
query = """
SELECT *
FROM `bigquery-public-data.google_analytics_sample.ga_sessions_20170715`;
"""

# Execute the query and store the results in a Pandas DataFrame
ex = client.query(query).to_dataframe()

# Display the first few rows
ex.head()
# Out:
#    visitorId  visitNumber     visitId  visitStartTime      date  \
# 0       <NA>            1  1500175678      1500175678  20170715
# 1       <NA>            1  1500140302      1500140302  20170715
# 2       <NA>            1  1500153151      1500153151  20170715
# 3       <NA>            1  1500103046      1500103046  20170715
# 4       <NA>            1  1500157730      1500157730  20170715
#
#                                               totals  \
# 0  {'visits': 1, 'hits': 15, 'pageviews': 11, 'ti...
# 1  {'visits': 1, 'hits': 15, 'pageviews': 9, 'tim...
# 2  {'visits': 1, 'hits': 15, 'pageviews': 14, 'ti...
# 3  {'visits': 1, 'hits': 15, 'pageviews': 15, 'ti...
# 4  {'visits': 1, 'hits': 16, 'pageviews': 15, 'ti...
#
#                                        trafficSource  \
# 0  {'referralPath': None, 'campaign': 'Data Share...
# 1  {'referralPath': None, 'campaign': '(not set)'...
# 2  {'referralPath': None, 'campaign': '(not set)'...
# 3  {'referralPath': None, 'campaign': '(not set)'...
# 4  {'referralPath': None, 'campaign': '(not set)'...
#
#                                               device  \
# 0  {'browser': 'Chrome', 'browserVersion': 'not a...
# 1  {'browser': 'Chrome', 'browserVersion': 'not a...
# 2  {'browser': 'Safari', 'browserVersion': 'not a...
# 3  {'browser': 'Opera Mini', 'browserVersion': 'n...
# 4  {'browser': 'Chrome', 'browserVersion': 'not a...
#
#                                           geoNetwork  \
# 0  {'continent': 'Europe', 'subContinent': 'Easte...
# 1  {'continent': 'Americas', 'subContinent': 'Nor...
# 2  {'continent': 'Americas', 'subContinent': 'Nor...
# 3  {'continent': 'Asia', 'subContinent': 'Souther...
# 4  {'continent': 'Americas', 'subContinent': 'Nor...
#
#                            customDimensions  \
# 0                                        []
# 1  [{'index': 4, 'value': 'North America'}]
# 2  [{'index': 4, 'value': 'North America'}]
# 3           [{'index': 4, 'value': 'APAC'}]
# 4  [{'index': 4, 'value': 'North America'}]
#
#                                                 hits        fullVisitorId  \
# 0  [{'hitNumber': 1, 'time': 0, 'hour': 20, 'minu...  8150256204624206878
# 1  [{'hitNumber': 1, 'time': 0, 'hour': 10, 'minu...  5465216125812676280
# 2  [{'hitNumber': 1, 'time': 0, 'hour': 14, 'minu...   394683673490644764
# 3  [{'hitNumber': 1, 'time': 0, 'hour': 0, 'minut...  0754507752413433588
# 4  [{'hitNumber': 1, 'time': 0, 'hour': 15, 'minu...  3134978009959363466
#
#   userId clientId channelGrouping  socialEngagementType
# 0   None     None      Affiliates  Not Socially Engaged
# 1   None     None  Organic Search  Not Socially Engaged
# 2   None     None  Organic Search  Not Socially Engaged
# 3   None     None  Organic Search  Not Socially Engaged
# 4   None     None  Organic Search  Not Socially Engaged

# %%
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   visitorId             0 non-null      Int64
#  1   visitNumber           1721 non-null   Int64
#  2   visitId               1721 non-null   Int64
#  3   visitStartTime        1721 non-null   Int64
#  4   date                  1721 non-null   object
#  5   totals                1721 non-null   object
#  6   trafficSource         1721 non-null   object
#  7   device                1721 non-null   object
#  8   geoNetwork            1721 non-null   object
#  9   customDimensions      1721 non-null   object
#  10  hits                  1721 non-null   object
#  11  fullVisitorId         1721 non-null   object
#  12  userId                0 non-null      object
#  13  clientId              0 non-null      object
#  14  channelGrouping       1721 non-null   object
#  15  socialEngagementType  1721 non-null   object
# dtypes: Int64(4), object(12)
# memory usage: 222.0+ KB

# %%
ex['channelGrouping'].unique()
# Out:
# array(['Affiliates', 'Organic Search', 'Referral', 'Social', 'Direct',
#        'Paid Search', 'Display'], dtype=object)

# %% [markdown]
# visitorId, userId, and clientId provide no useful information.

# %%
for col in ex.select_dtypes(object):
    try:
        ex[f'{col}_info'] = [x.keys() for x in ex[col]]
        print(ex[f'{col}_info'].value_counts())
        print("\n")
    except AttributeError:
        continue
# Out:
# totals_info
# (visits, hits, pageviews, timeOnSite, bounces, transactions, transactionRevenue, newVisits, screenviews, uniqueScreenviews, timeOnScreen, totalTransactionRevenue, sessionQualityDim)    1721
# Name: count, dtype: int64
#
#
# trafficSource_info
# (referralPath, campaign, source, medium, keyword, adContent, adwordsClickInfo, isTrueDirect, campaignCode)    1721
# Name: count, dtype: int64
#
#
# device_info
# (browser, browserVersion, browserSize, operatingSystem, operatingSystemVersion, isMobile, mobileDeviceBranding, mobileDeviceModel, mobileInputSelector, mobileDeviceInfo, mobileDeviceMarketingName, flashVersion, javaEnabled, language, screenColors, screenResolution, deviceCategory)    1721
# Name: count, dtype: int64
#
#
# geoNetwork_info
# (continent, subContinent, country, region, metro, city, cityId, networkDomain, latitude, longitude, networkLocation)    1721
# Name: count, dtype: int64

# %%
pd.DataFrame(ex['totals'].tolist()).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   visits                   1721 non-null   int64
#  1   hits                     1721 non-null   int64
#  2   pageviews                1721 non-null   int64
#  3   timeOnSite               752 non-null    float64
#  4   bounces                  966 non-null    float64
#  5   transactions             16 non-null     float64
#  6   transactionRevenue       16 non-null     float64
#  7   newVisits                1407 non-null   float64
#  8   screenviews              0 non-null      object
#  9   uniqueScreenviews        0 non-null      object
#  10  timeOnScreen             0 non-null      object
#  11  totalTransactionRevenue  16 non-null     float64
#  12  sessionQualityDim        1721 non-null   int64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 174.9+ KB

# %%
pd.DataFrame(ex['trafficSource'].tolist()).sample(5)
# Out:
#      referralPath          campaign    source     medium         keyword  \
# 271          None         (not set)    google    organic  (not provided)
# 833          None         (not set)    google    organic  (not provided)
# 292          None         (not set)    google    organic  (not provided)
# 1306         None         (not set)    google    organic  (not provided)
# 222          None  Data Share Promo  Partners  affiliate            None
#
#      adContent                                   adwordsClickInfo  \
# 271       None  {'campaignId': None, 'adGroupId': None, 'creat...
# 833       None  {'campaignId': None, 'adGroupId': None, 'creat...
# 292       None  {'campaignId': None, 'adGroupId': None, 'creat...
# 1306      None  {'campaignId': None, 'adGroupId': None, 'creat...
# 222       None  {'campaignId': None, 'adGroupId': None, 'creat...
#
#      isTrueDirect campaignCode
# 271          None         None
# 833          None         None
# 292          None         None
# 1306         None         None
# 222          None         None

# %%
pd.DataFrame(ex['device'].tolist()).head()
# Out:
#       browser                 browserVersion                    browserSize  \
# 0      Chrome  not available in demo dataset  not available in demo dataset
# 1      Chrome  not available in demo dataset  not available in demo dataset
# 2      Safari  not available in demo dataset  not available in demo dataset
# 3  Opera Mini  not available in demo dataset  not available in demo dataset
# 4      Chrome  not available in demo dataset  not available in demo dataset
#
#   operatingSystem         operatingSystemVersion  isMobile  \
# 0         Android  not available in demo dataset      True
# 1         Android  not available in demo dataset      True
# 2             iOS  not available in demo dataset      True
# 3       (not set)  not available in demo dataset      True
# 4       Macintosh  not available in demo dataset     False
#
#             mobileDeviceBranding              mobileDeviceModel  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#              mobileInputSelector               mobileDeviceInfo  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#        mobileDeviceMarketingName                   flashVersion javaEnabled  \
# 0  not available in demo dataset  not available in demo dataset        None
# 1  not available in demo dataset  not available in demo dataset        None
# 2  not available in demo dataset  not available in demo dataset        None
# 3  not available in demo dataset  not available in demo dataset        None
# 4  not available in demo dataset  not available in demo dataset        None
#
#                         language                   screenColors  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 screenResolution deviceCategory
# 0  not available in demo dataset         mobile
# 1  not available in demo dataset         mobile
# 2  not available in demo dataset         mobile
# 3  not available in demo dataset         mobile
# 4  not available in demo dataset        desktop

# %%
pd.DataFrame(ex['geoNetwork'].tolist()).head()
# Out:
#   continent      subContinent        country                         region  \
# 0    Europe    Eastern Europe        Czechia  not available in demo dataset
# 1  Americas  Northern America  United States  not available in demo dataset
# 2  Americas  Northern America         Canada                         Quebec
# 3      Asia     Southern Asia          India                      Karnataka
# 4  Americas  Northern America  United States                     California
#
#                                metro                           city  \
# 0      not available in demo dataset  not available in demo dataset
# 1      not available in demo dataset  not available in demo dataset
# 2                          (not set)                       Montreal
# 3                          (not set)                      Bengaluru
# 4  San Francisco-Oakland-San Jose CA                      Palo Alto
#
#                           cityId    networkDomain  \
# 0  not available in demo dataset           iol.cz
# 1  not available in demo dataset          cox.net
# 2  not available in demo dataset  unknown.unknown
# 3  not available in demo dataset  unknown.unknown
# 4  not available in demo dataset        (not set)
#
#                         latitude                      longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  networkLocation
# 0  not available in demo dataset
# 1  not available in demo dataset
# 2  not available in demo dataset
# 3  not available in demo dataset
# 4  not available in demo dataset

# %% [markdown]
# # Traffic and Conversion Analysis

# %% [markdown]
# Focus on visitors that has converted once or none from 2016-August to 2017-July

# %%
traffic_conversion_query = """
WITH conversions_summed AS (
    SELECT 
        fullVisitorId, 
        visitNumber, 
        date,
        channelGrouping,
        totals.transactions AS transactions, 
        totals.totalTransactionRevenue / 1000000 AS value,
        totals.newVisits AS newVisitor,
        trafficSource.source AS source,
        trafficSource.medium AS medium,
        trafficSource.isTrueDirect AS isTrueDirect,

        -- Conversion indicator
        (CASE WHEN totals.transactions IS NULL THEN 0 ELSE 1 END) AS conversion,
        
        -- Running total of conversions for each visitor
        SUM(CASE WHEN totals.transactions IS NULL THEN 0 ELSE 1 END) 
        OVER(
            PARTITION BY fullVisitorId
            ORDER BY visitNumber
            ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW    
        ) AS convSoFar
     
    FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
    WHERE _TABLE_SUFFIX BETWEEN '20160801' AND '20170801'
),

aggregated_features AS (
    SELECT 
        fullVisitorId, 
        MIN(date) AS first_visit_date, 
        MAX(newVisitor) AS isNewVisit,  -- Ensures that if a visitor was new at least once, we mark them as new
        MIN(CASE WHEN conversion = 1 THEN date ELSE NULL END) AS first_conversion_date  -- Find the first conversion date for each visitor
    FROM conversions_summed
    GROUP BY fullVisitorId
)

SELECT 
    c.fullVisitorId, 
    c.date, 
    c.conversion, 
    c.convSoFar,
    c.value, 
    c.source, 
    c.medium, 
    c.channelGrouping,
    c.isTrueDirect,
    c.newVisitor,
    
    -- Join aggregated features
    af.isNewVisit,
    CASE 
        WHEN c.date = af.first_conversion_date THEN 1 
        ELSE 0 
    END AS isFirstConversion

FROM conversions_summed c
LEFT JOIN aggregated_features af 
    ON c.fullVisitorId = af.fullVisitorId;
"""

# %%
# Execute the query and store the results in a Pandas DataFrame
traffic_df = client.query(traffic_conversion_query).to_dataframe()

# Display the first few rows
traffic_df.head()
# Out:
#          fullVisitorId      date  conversion  convSoFar  value  \
# 0  0001235242196175467  20161101           0          0    NaN
# 1  0015980521034237800  20161208           0          0    NaN
# 2  0034572692224994048  20161003           0          0    NaN
# 3  0040335064426021006  20160831           0          0    NaN
# 4  0047788902811115718  20161214           0          0    NaN
#
#                source    medium channelGrouping  isTrueDirect  newVisitor  \
# 0               baidu   organic  Organic Search          <NA>           1
# 1        facebook.com  referral          Social          <NA>           1
# 2               baidu   organic  Organic Search          <NA>           1
# 3       phandroid.com  referral        Referral          <NA>           1
# 4  adwords.google.com  referral        Referral          <NA>           1
#
#    isNewVisit  isFirstConversion
# 0           1                  0
# 1           1                  0
# 2           1                  0
# 3           1                  0
# 4           1                  0

# %%
# Turn 'date' to datetime object
traffic_df['date'] = pd.to_datetime(traffic_df['date'], format = "%Y%m%d")

# %%
# Save to CSV in a specific directory
traffic_df.to_csv("agg_data/conv_traf.csv", index=False)

# %% [markdown]
# # Google and Youtube Comparison

# %%
# Advertisement query
ad_query = """
    
SELECT
    fullVisitorId,
    date,
    totals.hits AS hits,
    totals.pageviews AS pageViews,
    totals.timeOnSite AS timeOnSite,
    totals.bounces AS bounces,
    totals.transactions AS transactions,
    totals.totalTransactionRevenue / 1000000 AS revenue,
    channelGrouping,
    
    -- Categorize the sources as 'Google' or 'YouTube'
    CASE 
        WHEN LOWER(trafficSource.source) LIKE '%google%' THEN 'Google'
        WHEN LOWER(trafficSource.source) LIKE '%youtube%' THEN 'YouTube'
        ELSE 'Other'  -- In case there are sources that do not match Google or YouTube
    END AS sourceCategory

FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
WHERE (_TABLE_SUFFIX BETWEEN '20160801' AND '20170801')
    AND (
        LOWER(trafficSource.source) LIKE '%google%' 
        OR LOWER(trafficSource.source) LIKE '%youtube%'
    );

"""

# %%
# Execute the query and store the results in a Pandas DataFrame
ad_df = client.query(ad_query).to_dataframe()

# Display the first few rows
ad_df.head()
# Out:
#          fullVisitorId      date  hits  pageViews  timeOnSite  bounces  \
# 0  1180797935503178227  20170514     1          1        <NA>        1
# 1  3172363110310924622  20170514     1          1        <NA>        1
# 2  3043098861438846312  20170514     1          1        <NA>        1
# 3  0410067780002939622  20170514     1          1        <NA>        1
# 4  1680957318855673062  20170514     1          1        <NA>        1
#
#    transactions  revenue channelGrouping sourceCategory
# 0          <NA>      NaN  Organic Search         Google
# 1          <NA>      NaN  Organic Search         Google
# 2          <NA>      NaN  Organic Search         Google
# 3          <NA>      NaN  Organic Search         Google
# 4          <NA>      NaN  Organic Search         Google

# %%
# Turn 'date' to datetime object
ad_df['date'] = pd.to_datetime(ad_df['date'], format = "%Y%m%d")

# %%
# Save to CSV in a specific directory
ad_df.to_csv("agg_data/ad.csv", index=False)
